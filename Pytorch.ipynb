# %% [markdown]
# <a href="https://colab.research.google.com/github/mvuddandi/DeepLearning/blob/main/Pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# False

# %%
a = torch.tensor([[50,60,90],
 [70,80,90],
     [100,110,120]])

b = torch.tensor([[200,210,220],
     [300,310,320],
     [400,410,420]])

# %%
c = torch.matmul(a,b)

# %%
c
# Out:
# tensor([[ 64000,  66000,  68000],
#         [ 74000,  76400,  78800],
#         [101000, 104300, 107600]])
